# %%
import cPickle
import pylab
from matplotlib import pyplot as plt
import numpy as np
from sklearn import preprocessing
import pandas as pd
# %matplotlib inline

# %%
with open("mr3_pa2_s16_results.pickle", "r") as f:
    data = cPickle.load(f)

# %%
data.keys()
# Out:
# ['respSel',
#  'corrLive',
#  'scan_freq',
#  'resp',
#  'rmsLive',
#  'sel',
#  'corrDark',
#  'kurtLive',
#  'normDark',
#  'live',
#  'stable',
#  'skewLive',
#  'normLive',
#  'darkRatioLive',
#  'MFELive',
#  'dark',
#  'ff',
#  'jumpDark',
#  'gainDark',
#  'name',
#  'gainLive',
#  'DELive',
#  'cal',
#  'rmsDark',
#  'jumpLive',
#  'DEDark']

# %% [markdown]
# We have looked at the basis statistics, now let's implement some simple statistical manipulations.

# %% [markdown]
# ## Grouping
# I would like to group the detectors based on the selected or not selected

# %%
# Define the tags that we are interested in
tags = ['corrLive', 'rmsLive', 'kurtLive', 'skewLive', 'normLive', \
        'darkRatioLive', 'MFELive', 'gainLive', 'DELive', 'jumpLive']

# %%
selected = data['sel']==1
deselected = data['sel']==0

# %%
selected_data = []
deselected_data = []
for tag in tags:
    selected_data.append(data[tag][selected])
    deselected_data.append(data[tag][deselected])

# %%
good_data = np.vstack(selected_data).T
bad_data = np.vstack(deselected_data).T

# %%
print good_data.shape
print bad_data.shape
# Out:
# (7488229, 10)
# (6273563, 10)

# %%
good_data_df = pd.DataFrame(good_data)
good_data_df.columns = tags
bad_data_df = pd.DataFrame(bad_data)
bad_data_df.columns = tags

# %%
print "Good Data:"
print good_data_df.describe()
print 
print "Bad Data:"
print bad_data_df.describe()
# Out:
# Good Data:
#            corrLive       rmsLive      kurtLive      skewLive      normLive  \
# count  7.488229e+06  7.488229e+06  7.488229e+06  7.488229e+06  7.488229e+06
# mean   9.939555e-01  1.442978e+03  1.578835e+00 -4.447728e-04  5.338309e+06
# std    7.109245e-03  7.142639e+02  2.088896e+00  1.075172e+00  6.226124e+06
# min    9.500005e-01  8.437833e+00 -4.997394e+00 -4.998052e+00  1.579575e+04
# 25%    9.926150e-01  9.961767e+02  3.349300e-01 -7.149229e-01  1.495942e+06
# 50%    9.963938e-01  1.299896e+03  1.227379e+00 -3.137847e-04  3.315818e+06
# 75%    9.982863e-01  1.705523e+03  2.291919e+00  7.145216e-01  6.884080e+06
# max    9.999995e-01  2.374234e+04  1.499987e+01  4.999719e+00  4.378115e+08
#
#        darkRatioLive       MFELive      gainLive        DELive      jumpLive
# count   7.488229e+06  7.488229e+06  7.488229e+06  7.488229e+06  7.488229e+06
# mean    8.299198e-01  8.198705e+03  9.800994e-01  1.505025e+05  2.376738e-03
# std     1.171682e-01  9.710919e+03  3.488618e-01  1.979382e+05  1.088012e-03
# min     5.000006e-01  3.418610e+01  3.761470e-03  3.646009e-11  4.112980e-05
# 25%     7.577398e-01  2.739277e+03  6.888465e-01  4.440577e+04  1.637183e-03
# 50%     8.557021e-01  5.050676e+03  1.030537e+00  8.741705e+04  2.110710e-03
# 75%     9.276483e-01  9.915610e+03  1.232064e+00  1.766379e+05  2.821282e-03
# max     9.999989e-01  7.407223e+05  1.385186e+01  1.393204e+07  9.999543e-03
#
# Bad Data:
#            corrLive       rmsLive      kurtLive      skewLive      normLive  \
# count  6.273563e+06  6.273563e+06  6.273563e+06  6.273563e+06  6.273563e+06
# mean   2.055138e+19  1.013206e+05  6.620327e+00 -3.200253e-02  2.373144e+06
# std    4.040766e+19  2.567832e+06  1.351399e+01  1.038931e+01  6.815281e+07
# min    0.000000e+00  0.000000e+00 -2.824165e+02 -2.185344e+02  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00 -4.668181e-02  0.000000e+00
# 50%    3.223561e-01  5.290780e+02  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    9.938011e-01  8.675560e+02  7.209612e+00  3.534521e-02  2.486048e+05
# max    1.000000e+20  3.489255e+08  1.103813e+02  2.029860e+02  2.060161e+10
#
#        darkRatioLive       MFELive      gainLive        DELive      jumpLive
# count   6.273563e+06  6.273563e+06  6.259078e+06  6.273563e+06  6.273563e+06
# mean    2.098202e-01  5.656564e+05  1.199227e+00  5.463693e+06  5.120527e+03
# std     3.361463e-01  1.170657e+07  1.547279e+02  9.458791e+07  1.030078e+06
# min     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  5.073454e-04
# 50%     0.000000e+00  1.413383e+03  0.000000e+00  6.325187e+03  7.728628e-04
# 75%     4.613441e-01  3.540363e+03  3.304518e-02  6.920552e+04  1.527605e-03
# max     9.999988e-01  9.465744e+08  1.140107e+05  5.947005e+09  2.683533e+08

# %%
good_data_df.hist(figsize=(15,15),bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x3d0003dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x3d0427d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x3d0b08d50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x3d0b7c050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x3d0c01090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x3d0c679d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x3d0ceebd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x3ceb643d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x3d0d870d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x3d0d96590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x3d0e72dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x3d0efac50>]],
#       dtype=object)

# %%
good_data_df.boxplot(column=['kurtLive', 'skewLive'])

# %% [markdown]
# Now we have grouped the detector data according to whether they are selected or not. For each detector, there are 10 features (attribute). One thing to notice is that for bad data, there are about 3e4 data points in gainLive that's nan. We need to clean that up first.

# %%
bad_data_df = bad_data_df.dropna(axis=0, how="any")

# %%
good_data = good_data_df.as_matrix()
bad_data = bad_data_df.as_matrix()

# %% [markdown]
# # PCA
# We are going to perform a principle component analysis on the ten properties to see if there is any chance of dimension reduction. Let's look at the good data first.
# ## Normalize
# Let's normalize the data first so that it's easier to compare.

# %%
std_scaler = preprocessing.StandardScaler().fit(good_data)

# %%
good_data_trans = std_scaler.transform(good_data)
bad_data_trans = std_scaler.transform(bad_data)

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA

# %%
sklearn_pca = PCA(n_components=None)
sklearn_pca.fit(good_data_trans)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
print sklearn_pca.explained_variance_ratio_
plt.bar(range(10),sklearn_pca.explained_variance_ratio_, )
# Out:
# [0.36402575 0.15918187 0.10000026 0.09538368 0.08190422 0.06959188
#  0.05991982 0.03186045 0.02251621 0.01561584]
# <Container object of 10 artists>

# %%
plt.imshow(sklearn_pca.get_covariance())

# %%
good_data_pca = sklearn_pca.transform(good_data_trans)
bad_data_pca = sklearn_pca.transform(bad_data_trans)

# %%
plt.scatter(good_data_pca[:1000,0], good_data_pca[:1000,1],alpha=0.1, color='r')
plt.scatter(bad_data_pca[:1000,0], bad_data_pca[:1000,1],alpha=0.1, color='b')

# %% [markdown]
# The two distributions looks clearly distinguishable. However, this may be because we are taking data in order, and maybe the first few TOD isn't representative enough. Let's apply random sampling in both groups and repeat the same procedures.

# %% [markdown]
# ## Random Sampling

# %%
n_samples = 10000
good_data = good_data_df.sample(n=n_samples).as_matrix()
bad_data = bad_data_df.sample(n=n_samples).as_matrix()

# %%
good_data_trans = std_scaler.transform(good_data)
bad_data_trans = std_scaler.transform(bad_data)
good_data_pca = sklearn_pca.transform(good_data_trans)
bad_data_pca = sklearn_pca.transform(bad_data_trans)

# %%
plt.scatter(good_data_pca[:1000,0], good_data_pca[:1000,1],alpha=0.1, color='r')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-125-fe23bd50efdb> in <module>()
# ----> 1 plt.scatter(good_data_pca[:1000,0], good_data_pca[:1000,1],alpha=0.1, color='r')
#
# /Users/yguan/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3433                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3434                          linewidths=linewidths, verts=verts,
# -> 3435                          edgecolors=edgecolors, data=data, **kwargs)
#    3436     finally:
#    3437         ax._hold = washold
#
# /Users/yguan/anaconda2/lib/python2.7/site-packages/mpl_toolkits/mplot3d/axes3d.pyc in scatter(self, xs, ys, zs, zdir, s, c, depthshade, *args, **kwargs)
#    2350             xs, ys, zs, s = cbook.delete_masked_points(xs, ys, zs, s)
#    2351
# -> 2352         patches = Axes.scatter(self, xs, ys, s=s, c=c, *args, **kwargs)
#    2353         if not cbook.iterable(zs):
#    2354             is_2d = True
#
# /Users/yguan/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /Users/yguan/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4026                 offsets=offsets,
#    4027                 transOffset=kwargs.pop('transform', self.transData),
# -> 4028                 alpha=alpha
#    4029                 )
#    4030         collection.set_transform(mtransforms.IdentityTransform())
#
# /Users/yguan/anaconda2/lib/python2.7/site-packages/matplotlib/collections.pyc in __init__(self, paths, sizes, **kwargs)
#     890         Collection.__init__(self, **kwargs)
#     891         self.set_paths(paths)
# --> 892         self.set_sizes(sizes)
#     893         self.stale = True
#     894
#
# /Users/yguan/anaconda2/lib/python2.7/site-packages/matplotlib/collections.pyc in set_sizes(self, sizes, dpi)
#     863             self._sizes = np.asarray(sizes)
#     864             self._transforms = np.zeros((len(self._sizes), 3, 3))
# --> 865             scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
#     866             self._transforms[:, 0, 0] = scale
#     867             self._transforms[:, 1, 1] = scale
#
# AttributeError: 'NoneType' object has no attribute 'sqrt'

# %%
plt.scatter(bad_data_pca[:,0], bad_data_pca[:,1],alpha=0.1, color='b')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-126-83ce3c1fd3b9> in <module>()
# ----> 1 plt.scatter(bad_data_pca[:,0], bad_data_pca[:,1],alpha=0.1, color='b')
#
# /Users/yguan/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3433                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3434                          linewidths=linewidths, verts=verts,
# -> 3435                          edgecolors=edgecolors, data=data, **kwargs)
#    3436     finally:
#    3437         ax._hold = washold
#
# /Users/yguan/anaconda2/lib/python2.7/site-packages/mpl_toolkits/mplot3d/axes3d.pyc in scatter(self, xs, ys, zs, zdir, s, c, depthshade, *args, **kwargs)
#    2350             xs, ys, zs, s = cbook.delete_masked_points(xs, ys, zs, s)
#    2351
# -> 2352         patches = Axes.scatter(self, xs, ys, s=s, c=c, *args, **kwargs)
#    2353         if not cbook.iterable(zs):
#    2354             is_2d = True
#
# /Users/yguan/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /Users/yguan/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4026                 offsets=offsets,
#    4027                 transOffset=kwargs.pop('transform', self.transData),
# -> 4028                 alpha=alpha
#    4029                 )
#    4030         collection.set_transform(mtransforms.IdentityTransform())
#
# /Users/yguan/anaconda2/lib/python2.7/site-packages/matplotlib/collections.pyc in __init__(self, paths, sizes, **kwargs)
#     890         Collection.__init__(self, **kwargs)
#     891         self.set_paths(paths)
# --> 892         self.set_sizes(sizes)
#     893         self.stale = True
#     894
#
# /Users/yguan/anaconda2/lib/python2.7/site-packages/matplotlib/collections.pyc in set_sizes(self, sizes, dpi)
#     863             self._sizes = np.asarray(sizes)
#     864             self._transforms = np.zeros((len(self._sizes), 3, 3))
# --> 865             scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
#     866             self._transforms[:, 0, 0] = scale
#     867             self._transforms[:, 1, 1] = scale
#
# AttributeError: 'NoneType' object has no attribute 'sqrt'

# %% [markdown]
# We see that it is polluted by overflow, let's try to clean that up by restricting the range of bad_data

# %%
_data_x = bad_data_pca[:,0]
_data_y = bad_data_pca[:,1]
sel = (_data_x < 100) & (_data_y < 100)
plt.scatter(_data_x[sel], _data_y[sel],alpha=0.1, color='b')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-039ee49e5736> in <module>()
#       2 _data_y = bad_data_pca[:,1]
#       3 sel = (_data_x < 100) & (_data_y < 100)
# ----> 4 plt.scatter(_data_x[sel], _data_y[sel],alpha=0.1, color='b')
#
# /Users/yguan/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3433                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3434                          linewidths=linewidths, verts=verts,
# -> 3435                          edgecolors=edgecolors, data=data, **kwargs)
#    3436     finally:
#    3437         ax._hold = washold
#
# /Users/yguan/anaconda2/lib/python2.7/site-packages/mpl_toolkits/mplot3d/axes3d.pyc in scatter(self, xs, ys, zs, zdir, s, c, depthshade, *args, **kwargs)
#    2350             xs, ys, zs, s = cbook.delete_masked_points(xs, ys, zs, s)
#    2351
# -> 2352         patches = Axes.scatter(self, xs, ys, s=s, c=c, *args, **kwargs)
#    2353         if not cbook.iterable(zs):
#    2354             is_2d = True
#
# /Users/yguan/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /Users/yguan/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4026                 offsets=offsets,
#    4027                 transOffset=kwargs.pop('transform', self.transData),
# -> 4028                 alpha=alpha
#    4029                 )
#    4030         collection.set_transform(mtransforms.IdentityTransform())
#
# /Users/yguan/anaconda2/lib/python2.7/site-packages/matplotlib/collections.pyc in __init__(self, paths, sizes, **kwargs)
#     890         Collection.__init__(self, **kwargs)
#     891         self.set_paths(paths)
# --> 892         self.set_sizes(sizes)
#     893         self.stale = True
#     894
#
# /Users/yguan/anaconda2/lib/python2.7/site-packages/matplotlib/collections.pyc in set_sizes(self, sizes, dpi)
#     863             self._sizes = np.asarray(sizes)
#     864             self._transforms = np.zeros((len(self._sizes), 3, 3))
# --> 865             scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
#     866             self._transforms[:, 0, 0] = scale
#     867             self._transforms[:, 1, 1] = scale
#
# AttributeError: 'NoneType' object has no attribute 'sqrt'

# %% [markdown]
# This looks much better, let me plot it together with the good data

# %%
plt.figure()
plt.scatter(good_data_pca[:,0], good_data_pca[:,1],alpha=0.1, color='r')
sel = (_data_x > -50) & (_data_x < 40) & (_data_y > -20) &(_data_y < 100)
plt.scatter(_data_x[sel], _data_y[sel],alpha=0.1, color='b')
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# There is already some discriminating power from the first variable in the pca transformed basis. Let's look at one additional dimension.

# %%
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib nbagg
# Out:
# Warning: Cannot change to a different GUI toolkit: nbagg. Using notebook instead.

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(good_data_pca[:,0], good_data_pca[:,1],good_data_pca[:,2], alpha=0.1, color='r')
sel = (_data_x > -50) & (_data_x < 40) & (_data_y > -20) &(_data_y < 100)
_data_z = bad_data_pca[:,2]
ax.scatter(_data_x[sel], _data_y[sel], _data_z[sel] ,alpha=0.1, color='b')
# Out:
# <img src="data:image/png;base64,..." width="432">
