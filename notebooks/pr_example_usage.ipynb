# %%
from todloop.utils.pixels import PixelReader
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
pr = PixelReader()

# %%
x, y = pr.get_x_y_array()
plt.plot(x,y,'r.')

# %%
plt.figure(figsize=[10,10])
# plot array
x, y = pr.get_x_y_array()
plt.plot(x,y,'r.')

# plot a set of pixels
x, y = pr.get_x_y(1)
plt.plot(x,y, 'b.',alpha=0.8, markersize=50)

x, y = pr.get_x_y(2)
plt.plot(x,y, 'b.',alpha=0.5, markersize=50)

x, y = pr.get_x_y(3)
plt.plot(x,y, 'b.',alpha=0.3, markersize=50)
