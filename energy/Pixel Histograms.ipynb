# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data_cov = np.genfromtxt('Unf_cov_pixhist.txt')
data_unc = np.genfromtxt('Unf_unc_pixhist.txt')

#data_cov = np.log(data_cov)
#data_unc = np.log(data_unc)

plt.figure(figsize=(12,7))

plt.step(*data_cov, label="Covered")
plt.step(*data_unc,label="Uncovered")
plt.xlabel('Number of Pixels')
plt.ylabel('Events')
plt.title('Pixels affected per Event 150 TODs')
plt.legend()
plt.show()

"""
# File Name:
file_name = 'Pix_hist' 
 
# Format Selection (Options: 'png', 'svg', 'eps')
file_format = 'svg'
 
plt.savefig(file_name + '.' + file_format,
            format=file_format,
            orientation='portrait',
            transparent=False,
            bbox_inches='tight',
            pad_inches=0.1)
"""
# Out:
# "\n# File Name:\nfile_name = 'Pix_hist' \n \n# Format Selection (Options: 'png', 'svg', 'eps')\nfile_format = 'svg'\n \nplt.savefig(file_name + '.' + file_format,\n            format=file_format,\n            orientation='portrait',\n            transparent=False,\n            bbox_inches='tight',\n            pad_inches=0.1)\n"

# %%
data_cov1 = np.genfromtxt('Unf_cov_pix.txt')
data_unc1 = np.genfromtxt('Unf_uncov_pix.txt')

#data_cov = np.log(data_cov)
#data_unc = np.log(data_unc)

plt.figure(figsize=(12,7))

plt.step(*data_cov1,alpha=0.8,label="Covered")
plt.step(*data_unc1,alpha=0.8,label="Uncovered")
plt.xlim(50,125)
plt.ylim(-1,5)
plt.xlabel('Number of Pixels')
plt.ylabel('Events')
plt.title('Pixels affected per Event 150 TODs')
plt.legend()
#plt.show()

"""
# File Name:
file_name = 'Pix_hist_long' 
 
# Format Selection (Options: 'png', 'svg', 'eps')
file_format = 'pdf'
 
plt.savefig(file_name + '.' + file_format,
            format=file_format,
            orientation='portrait',
            transparent=False,
            bbox_inches='tight',
            pad_inches=0.1)
"""
# Out:
# "\n# File Name:\nfile_name = 'Pix_hist_long' \n \n# Format Selection (Options: 'png', 'svg', 'eps')\nfile_format = 'pdf'\n \nplt.savefig(file_name + '.' + file_format,\n            format=file_format,\n            orientation='portrait',\n            transparent=False,\n            bbox_inches='tight',\n            pad_inches=0.1)\n"
